# %%
import copy, numpy as np
import tensorflow as tf
import time
#from dask.dataframe.io.tests.test_csv import timeseries
#from dask.array.stats import kurtosis
# from nltk.twitter.twitter_demo import yesterday
# from nltk.twitter.twitter_demo import yesterday
np.random.seed(0)  
start = time.clock()
def add_layer(inputs, in_size, out_size, activation_function=None):
    # add one more layer and return the output of this layer
    Weights = tf.Variable(tf.random_normal([in_size, out_size]))
    biases = tf.Variable(tf.zeros([1, out_size]) + 0.1)
    Wx_plus_b = tf.matmul(inputs, Weights) + biases
    if activation_function is None:
        outputs = Wx_plus_b
    else:
        outputs = activation_function(Wx_plus_b)
    return outputs



XX = []
yy = []


# compute sigmoid nonlinearity  
def sigmoid(x):  
    output = 1/(1+np.exp(-x))  
    return output  
def ApEn(U, m, r):

    def _maxdist(x_i, x_j):
        return max([abs(ua - va) for ua, va in zip(x_i, x_j)])

    def _phi(m):
        x = [[U[j] for j in range(i, i + m - 1 + 1)] for i in range(N - m + 1)]
        C = [len([1 for x_j in x if _maxdist(x_i, x_j) <= r]) / (N - m + 1.0) for x_i in x]
        return (N - m + 1.0)**(-1) * sum(np.log(C))

    N = len(U)

    return abs(_phi(m+1) - _phi(m))
# convert output of sigmoid function to its derivative  
def sigmoid_output_to_derivative(output):  
    return output*(1-output) 
#import matplotlib.pyplot as plt
import math
#import csv
import numpy as np
import pandas as pd
import random

def entropy(*c):
    result=-1;
    if(len(c)>0):
        result=0;
    for x in c:
        result+=(-x)*math.log(x,2)
    return result;
def dateTransfer(x):
    x = x.split('_')[1:4]
    x = '_'.join(x)
    return x
def ApEn(U, m, r):

    def _maxdist(x_i, x_j):
        return max([abs(ua - va) for ua, va in zip(x_i, x_j)])

    def _phi(m):
        x = [[U[j] for j in range(i, i + m - 1 + 1)] for i in range(N - m + 1)]
        C = [len([1 for x_j in x if _maxdist(x_i, x_j) <= r]) / (N - m + 1.0) for x_i in x]
        return (N - m + 1.0)**(-1) * sum(np.log(C))

    N = len(U)

    return abs(_phi(m+1) - _phi(m))
def Get_average(list):
    sum=0
    for item in list:
        sum+=item
    return sum/len(list)
def averagejerk(A):
    L=[]
    for i in range(0,len(A)-1):
        L.append(A[i+1]-A[i])
    result=Get_average(L)
    return result
def averageabsolutejerk(A):
    L=[]
    for i in range(0,len(A)-1):
        L.append(abs(A[i+1]-A[i]))
    result=Get_average(L)
    return result 
air=pd.read_csv('newtables/air_res_vis_store.csv',encoding='latin1')
hpg=pd.read_csv('newtables/hpg_res_store.csv',encoding='latin1')
date=pd.read_csv('newtables/date_info_new_new_new.csv',encoding='latin1')
date_temp=date.set_index('Date', drop=False)
alpha = 0.1  
input_dim = 6  
hidden_dim = 20  
output_dim = 1

air_temp = air.set_index("air_store_id", drop=False)
hpg_temp = hpg.set_index('hpg_store_id', drop=False)

synapse_0 = 2*np.random.random((input_dim,hidden_dim)) - 1  
synapse_1 = 2*np.random.random((hidden_dim,output_dim)) - 1  
synapse_h = 2*np.random.random((hidden_dim,hidden_dim)) - 1  
   
synapse_0_update = np.zeros_like(synapse_0)  
synapse_1_update = np.zeros_like(synapse_1)  
synapse_h_update = np.zeros_like(synapse_h)

timeline=30
for j in range(100):
#     print(j)
    x=random.randint(0,len(air.air_store_id)-1)
    name=air.air_store_id[x]
    #print(name)
    timelist=air_temp.loc[name,air.columns[434]:air.columns[911]]
    genre=air_temp.loc[name,air.columns[912]:air.columns[925]]
    area=air_temp.loc[name,air.columns[926]:air.columns[1028]]
    position=air_temp.loc[name,air.columns[1029]:air.columns[1030]]
    for p in range(0,len(timelist)):
        if(timelist[p] != 0):
            t = p
            break
    timelist=timelist[t:-1]
    y=random.randint(0,len(timelist)-timeline-1)
    timeseries=timelist[y:y+timeline-1]
    result=timelist[y+timeline]
    prediction=0
    Error=0
    Kurtosis=timeseries.kurt()
    Standard=timeseries.std()
    Entropy=ApEn(timeseries, 2, 0.2*Standard)
    AverageJerk=averagejerk(timeseries)
    AverageAbsoluteJerk=averageabsolutejerk(timeseries)
    Mean=timeseries.mean()
    Median=timeseries.median()
    Max=timeseries.max()
    Min=timeseries.min()
    Feature=[Kurtosis,Entropy,AverageJerk,AverageAbsoluteJerk,Mean,Median,Standard,Max,Min]
    Today_date=air.columns[y+434+t+timeline]
    Yesterday_date=air.columns[y+434+t+timeline-1]
    Yesterday_visitor=air.loc[x][y+434+t+timeline-1]
    yesterday=dateTransfer(Yesterday_date)
    today=dateTransfer(Today_date)
    Today=date_temp.loc[today,date.columns[2]:date.columns[7]]
    Yesterday=date_temp.loc[yesterday,date.columns[2]:date.columns[7]]
    Yesterday=list(Yesterday)
    genre=list(genre)
    area =list(area)
    position=list(position)
    Today=list(Today)
#     Yesterday.append(Yesterday_visitor)
    layer_2_deltas = list()  
    layer_1_values = list()  
    layer_1_values.append(np.zeros(hidden_dim))
    X = []
    for each_item in genre:
        X.append(each_item)
    for each_item in area:
        X.append(each_item)
    for each_item in position:
        X.append(each_item)
    for each_item in Feature:
        X.append(each_item)
    for each_item in Today:
        X.append(each_item)
    for each_item in Yesterday:
        X.append(each_item)
    y = [result]
    # X=list(X)
    XX.append(X)
    yy.append(y)
#= np.array([X])
# define placeholder for inputs to network
xs = tf.placeholder(tf.float32, [None, 140])
ys = tf.placeholder(tf.float32, [None, 1])
# add hidden layer
l1 = add_layer(xs, 140, 500, activation_function=tf.nn.sigmoid)

l2 = add_layer(l1, 500, 300, activation_function=tf.nn.sigmoid)
l3 = add_layer(l2, 300, 100, activation_function=tf.nn.sigmoid)
                # add output layer
prediction = add_layer(l3, 100, 1, activation_function=None)

loss = tf.reduce_mean(tf.reduce_sum(tf.square(ys - prediction),reduction_indices=[1]))
train_step = tf.train.GradientDescentOptimizer(0.001).minimize(loss)

init = tf.global_variables_initializer()
#sess = tf.Session()


saver = tf.train.Saver()

with tf.Session() as sess:
    sess.run(init)
    for jj in range(10000):
        sess.run(train_step, feed_dict={xs: XX, ys: yy})
    saver.save(sess, "restaurant/model.ckpt")





statustraining = np.zeros((39, 30))
rnn_result = []


sample = pd.read_csv('restaurant/sample_submission.csv')
sampleInfo = sample.id

sampleId = []
sampleDate = []

air_id = air.air_store_id

for kk in range(0,len(sampleInfo)):

    sampleId.append(sampleInfo[kk].split("_")[0] + '_' + sampleInfo[kk].split("_")[1])
    sampleDate.append(sampleInfo[kk].split("_")[2])


sampleId = list(set(sampleId))
#print(sampleId)
#print(sampleDate)
dateInfo = date.Date

sampleXX = []

print(len(dateInfo))

for pp in range(0,len(sampleId)):
    for qq in range(0,len(air_id)):
        if(sampleId[pp] == air_id[qq]):
            name = air_id[qq]
            timelist = air_temp.loc[name, air.columns[434]:air.columns[911]]
            timelist = timelist[len(timelist)-30:len(timelist)]
            genre = air_temp.loc[name, air.columns[912]:air.columns[925]]
            area = air_temp.loc[name, air.columns[926]:air.columns[1028]]
            position = air_temp.loc[name, air.columns[1029]:air.columns[1030]]
            timeseries = timelist

            for zz in range(0, 39):

                Kurtosis = timeseries.kurt()
                Standard = timeseries.std()
                Entropy = ApEn(timeseries, 2, 0.2 * Standard)
                AverageJerk = averagejerk(timeseries)
                AverageAbsoluteJerk = averageabsolutejerk(timeseries)
                Mean = timeseries.mean()
                Median = timeseries.median()
                Max = timeseries.max()
                Min = timeseries.min()
                Feature = [Kurtosis, Entropy, AverageJerk, AverageAbsoluteJerk, Mean, Median, Standard, Max, Min]
                Today_date = dateInfo[478 + zz]
                Yesterday_date = dateInfo[478 + zz - 1]
                Yesterday_visitor = timelist[len(timelist) - 1]
                #yesterday = dateTransfer(Yesterday_date)
                #today = dateTransfer(Today_date)
                Today = date_temp.loc[Today_date, date.columns[2]:date.columns[7]]
                Yesterday = date_temp.loc[Yesterday_date, date.columns[2]:date.columns[7]]
                Yesterday = list(Yesterday)
                genre = list(genre)
                area = list(area)
                position = list(position)
                Today = list(Today)
#                 Yesterday.append(Yesterday_visitor)
                layer_2_deltas = list()
                layer_1_values = list()
                layer_1_values.append(np.zeros(hidden_dim))
                #print(area)
                sampleX = []
                for each_item in genre:
                    sampleX.append(each_item)
                for each_item in area:
                    sampleX.append(each_item)
                for each_item in position:
                    sampleX.append(each_item)
                for each_item in Feature:
                    sampleX.append(each_item)
                for each_item in Today:
                    sampleX.append(each_item)
                for each_item in Yesterday:
                    sampleX.append(each_item)

                #print(sampleX)
                sampleXX.append(sampleX)

                with tf.Session() as sessss:

                    saver.restore(sessss, "restaurant/model.ckpt")

                    answer = sessss.run(prediction, feed_dict={xs: [sampleXX[zz]]})


                statustraining[zz]=timeseries
                for each_item in answer:
                    print(each_item)
                    rnn_result.append(each_item)

                for yyy in range(29):
                    timeseries[yyy] = timeseries[yyy + 1]
                    timeseries[29] = answer


            sampleXX = []
            

            
np.savetxt('restaurant/RNN_B_Result.csv', rnn_result, delimiter=',');
# Out:
# F:\Anaconda\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# 517
# INFO:tensorflow:Restoring parameters from restaurant/model.ckpt
# [7.5254836]
# INFO:tensorflow:Restoring parameters from restaurant/model.ckpt
# [9.380737]
# INFO:tensorflow:Restoring parameters from restaurant/model.ckpt
# [11.981335]
# INFO:tensorflow:Restoring parameters from restaurant/model.ckpt
# [12.74932]
# INFO:tensorflow:Restoring parameters from restaurant/model.ckpt
# [13.218326]
# INFO:tensorflow:Restoring parameters from restaurant/model.ckpt
# [12.828929]
# INFO:tensorflow:Restoring parameters from restaurant/model.ckpt
# [12.783002]
# INFO:tensorflow:Restoring parameters from restaurant/model.ckpt
# [12.645765]
# ...

# %%
hello = tf.constant('Hello, TensorFlow!')
sess = tf.Session()
print(sess.run(hello))
# Out:
# b'Hello, TensorFlow!'
